# %% [markdown]
# Fetching dataset from Roboflow with API Key

# %%
import os

os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"
os.environ["OMP_NUM_THREADS"] = "1"

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="Q1flzyg1J8Z2OMweLXf3")
project = rf.workspace("weapon-mpr3p").project("ddr-dataset-yyvzp")
version = project.version(1)
dataset = version.download("folder")
# Out:
# Requirement already satisfied: roboflow in d:\konda\envs\basic_env\lib\site-packages (1.3.1)
# Requirement already satisfied: certifi in d:\konda\envs\basic_env\lib\site-packages (from roboflow) (2026.2.25)
# Requirement already satisfied: idna==3.7 in d:\konda\envs\basic_env\lib\site-packages (from roboflow) (3.7)
# Requirement already satisfied: cycler in d:\konda\envs\basic_env\lib\site-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\konda\envs\basic_env\lib\site-packages (from roboflow) (1.5.0)
# Requirement already satisfied: matplotlib in d:\konda\envs\basic_env\lib\site-packages (from roboflow) (3.10.8)
# Requirement already satisfied: numpy>=1.18.5 in d:\konda\envs\basic_env\lib\site-packages (from roboflow) (2.3.3)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in d:\konda\envs\basic_env\lib\site-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in d:\konda\envs\basic_env\lib\site-packages (from roboflow) (12.2.0)
# Requirement already satisfied: pi-heif<2 in d:\konda\envs\basic_env\lib\site-packages (from roboflow) (1.3.0)
# Requirement already satisfied: pillow-avif-plugin<2 in d:\konda\envs\basic_env\lib\site-packages (from roboflow) (1.5.5)
# Requirement already satisfied: python-dateutil in d:\konda\envs\basic_env\lib\site-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in d:\konda\envs\basic_env\lib\site-packages (from roboflow) (1.2.2)
# Requirement already satisfied: requests in d:\konda\envs\basic_env\lib\site-packages (from roboflow) (2.33.1)
# Requirement already satisfied: six in d:\konda\envs\basic_env\lib\site-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in d:\konda\envs\basic_env\lib\site-packages (from roboflow) (2.6.3)
# Requirement already satisfied: tqdm>=4.41.0 in d:\konda\envs\basic_env\lib\site-packages (from roboflow) (4.67.3)
# Requirement already satisfied: PyYAML>=5.3.1 in d:\konda\envs\basic_env\lib\site-packages (from roboflow) (6.0.3)
# Requirement already satisfied: requests_toolbelt in d:\konda\envs\basic_env\lib\site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: filetype in d:\konda\envs\basic_env\lib\site-packages (from roboflow) (1.2.0)
# Requirement already satisfied: typer>=0.12.0 in d:\konda\envs\basic_env\lib\site-packages (from roboflow) (0.24.1)
# Requirement already satisfied: colorama in d:\konda\envs\basic_env\lib\site-packages (from tqdm>=4.41.0->roboflow) (0.4.6)
# Requirement already satisfied: click>=8.2.1 in d:\konda\envs\basic_env\lib\site-packages (from typer>=0.12.0->roboflow) (8.3.2)
# Requirement already satisfied: shellingham>=1.3.0 in d:\konda\envs\basic_env\lib\site-packages (from typer>=0.12.0->roboflow) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in d:\konda\envs\basic_env\lib\site-packages (from typer>=0.12.0->roboflow) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in d:\konda\envs\basic_env\lib\site-packages (from typer>=0.12.0->roboflow) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\konda\envs\basic_env\lib\site-packages (from rich>=12.3.0->typer>=0.12.0->roboflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\konda\envs\basic_env\lib\site-packages (from rich>=12.3.0->typer>=0.12.0->roboflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in d:\konda\envs\basic_env\lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer>=0.12.0->roboflow) (0.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in d:\konda\envs\basic_env\lib\site-packages (from matplotlib->roboflow) (1.3.3)
# Requirement already satisfied: fonttools>=4.22.0 in d:\konda\envs\basic_env\lib\site-packages (from matplotlib->roboflow) (4.62.1)
# Requirement already satisfied: packaging>=20.0 in d:\konda\envs\basic_env\lib\site-packages (from matplotlib->roboflow) (25.0)
# Requirement already satisfied: pyparsing>=3 in d:\konda\envs\basic_env\lib\site-packages (from matplotlib->roboflow) (3.3.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\konda\envs\basic_env\lib\site-packages (from requests->roboflow) (3.4.7)
# loading Roboflow workspace...
# loading Roboflow project...

# %% [markdown]
# Training Model with YOLO

# %%
# !pip install ultralytics
# Out:
# Requirement already satisfied: ultralytics in d:\konda\envs\basic_env\lib\site-packages (8.4.37)
# Requirement already satisfied: numpy>=1.23.0 in d:\konda\envs\basic_env\lib\site-packages (from ultralytics) (2.3.3)
# Requirement already satisfied: matplotlib>=3.3.0 in d:\konda\envs\basic_env\lib\site-packages (from ultralytics) (3.10.8)
# Requirement already satisfied: opencv-python>=4.6.0 in d:\konda\envs\basic_env\lib\site-packages (from ultralytics) (4.13.0.92)
# Requirement already satisfied: pillow>=7.1.2 in d:\konda\envs\basic_env\lib\site-packages (from ultralytics) (12.2.0)
# Requirement already satisfied: pyyaml>=5.3.1 in d:\konda\envs\basic_env\lib\site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in d:\konda\envs\basic_env\lib\site-packages (from ultralytics) (2.33.1)
# Requirement already satisfied: scipy>=1.4.1 in d:\konda\envs\basic_env\lib\site-packages (from ultralytics) (1.16.2)
# Requirement already satisfied: torch>=1.8.0 in d:\konda\envs\basic_env\lib\site-packages (from ultralytics) (2.11.0)
# Requirement already satisfied: torchvision>=0.9.0 in d:\konda\envs\basic_env\lib\site-packages (from ultralytics) (0.26.0)
# Requirement already satisfied: psutil>=5.8.0 in d:\konda\envs\basic_env\lib\site-packages (from ultralytics) (7.1.0)
# Requirement already satisfied: polars>=0.20.0 in d:\konda\envs\basic_env\lib\site-packages (from ultralytics) (1.39.3)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in d:\konda\envs\basic_env\lib\site-packages (from ultralytics) (2.0.18)
# Requirement already satisfied: contourpy>=1.0.1 in d:\konda\envs\basic_env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in d:\konda\envs\basic_env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\konda\envs\basic_env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\konda\envs\basic_env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in d:\konda\envs\basic_env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=3 in d:\konda\envs\basic_env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in d:\konda\envs\basic_env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.39.3 in d:\konda\envs\basic_env\lib\site-packages (from polars>=0.20.0->ultralytics) (1.39.3)
# Requirement already satisfied: six>=1.5 in d:\konda\envs\basic_env\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\konda\envs\basic_env\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in d:\konda\envs\basic_env\lib\site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.26 in d:\konda\envs\basic_env\lib\site-packages (from requests>=2.23.0->ultralytics) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in d:\konda\envs\basic_env\lib\site-packages (from requests>=2.23.0->ultralytics) (2026.2.25)
# Requirement already satisfied: filelock in d:\konda\envs\basic_env\lib\site-packages (from torch>=1.8.0->ultralytics) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in d:\konda\envs\basic_env\lib\site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools<82 in d:\konda\envs\basic_env\lib\site-packages (from torch>=1.8.0->ultralytics) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in d:\konda\envs\basic_env\lib\site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in d:\konda\envs\basic_env\lib\site-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in d:\konda\envs\basic_env\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in d:\konda\envs\basic_env\lib\site-packages (from torch>=1.8.0->ultralytics) (2026.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\konda\envs\basic_env\lib\site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\konda\envs\basic_env\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)

# %%
from ultralytics import YOLO

model = YOLO("yolo26n-cls.pt")

model.train(
    data=dataset.location,
    epochs=5,
    imgsz=224,
    batch=64,
    name="ddr-224-yolo26-nano",
    amp=False,
    device=0,
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.46 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.37  Python-3.11.13 torch-2.11.0+cu128 CUDA:0 (NVIDIA GeForce GTX 1650 Ti, 4096MiB)
# engine\trainer: agnostic_nms=False, amp=False, angle=1.0, augment=False, auto_augment=randaugment, batch=64, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=c:\Users\ASUS\Downloads\mulmed\praktek\diabetic-retinopathy-classification-for-study-group\DDR-dataset-1, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=5, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=224, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo26n-cls.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=ddr-224-yolo26-nano2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\ASUS\Downloads\mulmed\praktek\diabetic-retinopathy-classification-for-study-group\runs\classify\ddr-224-yolo26-nano2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# train: C:\Users\ASUS\Downloads\mulmed\praktek\diabetic-retinopathy-classification-for-study-group\DDR-dataset-1\train... found 9498 images in 6 classes
# val: C:\Users\ASUS\Downloads\mulmed\praktek\diabetic-retinopathy-classification-for-study-group\DDR-dataset-1\valid... found 2721 images in 6 classes
# test: C:\Users\ASUS\Downloads\mulmed\praktek\diabetic-retinopathy-classification-for-study-group\DDR-dataset-1\test... found 1354 images in 6 classes
# Overriding model.yaml nc=1000 with nc=6
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  10                  -1  1    337926  ultralytics.nn.modules.head.Classify         [256, 6]
# YOLO26n-cls summary: 86 layers, 1,538,790 parameters, 1,538,790 gradients, 3.3 GFLOPs
# Transferred 234/236 items from pretrained weights
# train: Fast image access  (ping: 0.40.4 ms, read: 11.75.5 MB/s, size: 4.7 KB)
# train: Scanning C:\Users\ASUS\Downloads\mulmed\praktek\diabetic-retinopathy-classification-for-study-group\DDR-dataset-1\train... 9498 images, 0 corrupt: 100% ━━━━━━━━━━━━ 9498/9498 9.4Mit/s 0.0s
# val: Fast image access  (ping: 0.60.6 ms, read: 5.52.2 MB/s, size: 4.4 KB)
# val: Scanning C:\Users\ASUS\Downloads\mulmed\praktek\diabetic-retinopathy-classification-for-study-group\DDR-dataset-1\valid... 2721 images, 0 corrupt: 100% ━━━━━━━━━━━━ 2721/2721  0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001, momentum=0.9) with parameter groups 39 weight(decay=0.0), 40 weight(decay=0.0005), 40 bias(decay=0.0)
# Image sizes 224 train, 224 val
# Using 8 dataloader workers
# Logging results to C:\Users\ASUS\Downloads\mulmed\praktek\diabetic-retinopathy-classification-for-study-group\runs\classify\ddr-224-yolo26-nano2
# Starting training for 5 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#         1/5       1.4G       1.17         26        224: 100% ━━━━━━━━━━━━ 149/149 3.9it/s 38.3s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 22/22 7.9it/s 2.8s0.1s
#                    all      0.683      0.999
#
#       Epoch    GPU_mem       loss  Instances       Size
#         2/5       1.5G      0.837         26        224: 100% ━━━━━━━━━━━━ 149/149 5.7it/s 26.0s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 22/22 8.5it/s 2.6s0.1s
#                    all      0.713      0.999
#
#       Epoch    GPU_mem       loss  Instances       Size
#         3/5       1.5G     0.7788         26        224: 100% ━━━━━━━━━━━━ 149/149 5.4it/s 27.4s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 22/22 6.6it/s 3.3s0.2s
#                    all      0.713      0.999
#
#       Epoch    GPU_mem       loss  Instances       Size
#         4/5       1.5G     0.7197         26        224: 100% ━━━━━━━━━━━━ 149/149 5.4it/s 27.6s0.2ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 22/22 7.8it/s 2.8s0.1s
#                    all       0.73      0.999
#
#       Epoch    GPU_mem       loss  Instances       Size
#         5/5       1.5G     0.6553         26        224: 100% ━━━━━━━━━━━━ 149/149 5.8it/s 25.9s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 22/22 7.3it/s 3.0s0.1s
#                    all      0.765      0.999
#
# 5 epochs completed in 0.046 hours.
# Optimizer stripped from C:\Users\ASUS\Downloads\mulmed\praktek\diabetic-retinopathy-classification-for-study-group\runs\classify\ddr-224-yolo26-nano2\weights\last.pt, 3.2MB
# Optimizer stripped from C:\Users\ASUS\Downloads\mulmed\praktek\diabetic-retinopathy-classification-for-study-group\runs\classify\ddr-224-yolo26-nano2\weights\best.pt, 3.2MB
#
# Validating C:\Users\ASUS\Downloads\mulmed\praktek\diabetic-retinopathy-classification-for-study-group\runs\classify\ddr-224-yolo26-nano2\weights\best.pt...
# Ultralytics 8.4.37  Python-3.11.13 torch-2.11.0+cu128 CUDA:0 (NVIDIA GeForce GTX 1650 Ti, 4096MiB)
# YOLO26n-cls summary (fused): 47 layers, 1,533,710 parameters, 0 gradients, 3.2 GFLOPs
# train: C:\Users\ASUS\Downloads\mulmed\praktek\diabetic-retinopathy-classification-for-study-group\DDR-dataset-1\train... found 9498 images in 6 classes
# val: C:\Users\ASUS\Downloads\mulmed\praktek\diabetic-retinopathy-classification-for-study-group\DDR-dataset-1\valid... found 2721 images in 6 classes
# test: C:\Users\ASUS\Downloads\mulmed\praktek\diabetic-retinopathy-classification-for-study-group\DDR-dataset-1\test... found 1354 images in 6 classes
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 22/22 6.4it/s 3.4s0.2s
#                    all      0.765      0.999
# Speed: 0.2ms preprocess, 0.8ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to C:\Users\ASUS\Downloads\mulmed\praktek\diabetic-retinopathy-classification-for-study-group\runs\classify\ddr-224-yolo26-nano2
# ultralytics.utils.metrics.ClassifyMetrics object with attributes:
#
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x000001BBB8B007D0>
# curves: []
# curves_results: []
# fitness: 0.8820286691188812
# keys: ['metrics/accuracy_top1', 'metrics/accuracy_top5']
# results_dict: {'metrics/accuracy_top1': 0.7647923827171326, 'metrics/accuracy_top5': 0.9992649555206299, 'fitness': 0.8820286691188812}
# save_dir: WindowsPath('C:/Users/ASUS/Downloads/mulmed/praktek/diabetic-retinopathy-classification-for-study-group/runs/classify/ddr-224-yolo26-nano2')
# speed: {'preprocess': 0.17954924660046037, 'inference': 0.8452675854455199, 'loss': 0.0002714810734898067, 'postprocess': 0.0005527747157338067}
# top1: 0.7647923827171326
# top5: 0.9992649555206299
